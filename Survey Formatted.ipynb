# %%
import pandas as pd

# Load the dataset
file_path = 'D:/Flood_Project/Survey_dataset/Survey Formatted/final_research.csv'
df = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
df.head()
# Out:
# C:\Users\hq8312\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
#    Unnamed: 0       Start Date         End Date Response Type      IP Address  \
# 0           0  8/16/2024 14:23  8/16/2024 14:28    IP Address   12.237.206.12
# 1           1  8/16/2024 14:30  8/16/2024 14:42    IP Address     99.116.2.69
# 2           2  8/16/2024 16:10  8/16/2024 16:23    IP Address  73.145.247.127
# 3           3   8/17/2024 8:36   8/17/2024 8:43    IP Address   216.24.177.23
# 4           4  8/17/2024 11:31  8/17/2024 11:41    IP Address   73.145.108.93
#
#    Progress  Duration (in seconds)  Finished    Recorded Date  \
# 0       100                    303      True  8/16/2024 14:28
# 1       100                    711      True  8/16/2024 14:42
# ...

# %%
# Clean up non-numeric values in the relevant columns, treating them as NaN if they cannot be converted
df['No_Vhcl_hhl'] = pd.to_numeric(df['No_Vhcl_hhl'], errors='coerce')
df['No_workingppl_hhl'] = pd.to_numeric(df['No_workingppl_hhl'], errors='coerce')

# Now re-apply the function to create the new column after cleaning up the data
def classify_vehicle_availability(row):
    vehicles = row['No_Vhcl_hhl']
    workers = row['No_workingppl_hhl']
    
    if pd.isna(vehicles) or pd.isna(workers):
        return 'Unknown'
    
    if vehicles == 0:
        return '0 Autos'
    elif 0 < vehicles < workers:
        return 'Autos > 0 & < Workers'
    elif vehicles >= workers:
        return 'Autos ≥ Workers'
    else:
        return 'Unknown'

# Apply the function again
df['Vehicle_Availability'] = df.apply(classify_vehicle_availability, axis=1)

# %%
df['Vehicle_Availability']
# Out:
# 0            Autos ≥ Workers
# 1            Autos ≥ Workers
# 2                    0 Autos
# 3      Autos > 0 & < Workers
# 4            Autos ≥ Workers
#                ...
# 899    Autos > 0 & < Workers
# 900    Autos > 0 & < Workers
# 901          Autos ≥ Workers
# 902    Autos > 0 & < Workers
# 903    Autos > 0 & < Workers
# Name: Vehicle_Availability, Length: 904, dtype: object

# %%
# Export the updated dataset to a CSV file
output_file_path = 'D:/Flood_Project/Survey_dataset/Survey Formatted/more_final_research.csv'
df.to_csv(output_file_path, index=False)
