# %%
import os
os.chdir("D:/Twitter_Project/Google_Review/Mogo")

# %%
import serpapi

# %%
# !pip install serpapi

# %%
api_key = '5728c2f19331260824d1feb68e8770590b09423c38f78741f5bf7df5ff4c139a'
client = serpapi.Client(api_key = api_key)
results = client.search({ 'engine': 'google_maps', 'type':'search','q': 'Mogo Bikeshare Mogo Detroit','ll': '@42.331429, -83.045753,3z',
                         'start':20, })
print(results)
# Out:
# {
#     "search_metadata": {
#         "id": "6789b5a47f56ac9fa91cf468",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/591869eb66923498/6789b5a47f56ac9fa91cf468.json",
#         "created_at": "2025-01-17 01:43:00 UTC",
#         "processed_at": "2025-01-17 01:43:00 UTC",
# ...

# %%
import pandas as pd

# %%
data = results

# %%
# Check if local_results key exists in the data
if 'local_results' in data:
    # Extract the list of local results
    local_results = data['local_results']
    
    # Convert the list of dictionaries into a DataFrame
    local_results_df_2 = pd.DataFrame(local_results)

# %%
local_results_df_2.head(5)
# Out:
#    position                                         title  \
# 0         1            Mogo Bikeshare-Henry Ford Hospital
# 1         2                                MoGo Bikeshare
# 2         3       MoGo Bikeshare: Livernois & Florence St
# 3         4  MoGo Bikeshare-New Center 2nd & W Grand Blvd
# 4         5                                  MoGo Station
#
#                       place_id                                data_id  \
# 0  ChIJCXLiTGHNJIgRf3jpE96wE5w  0x8824cd614ce27209:0x9c13b0de13e9787f
# 1  ChIJ_XJ3sa3PJIgRQ0JaySPAjHA  0x8824cfadb17772fd:0x708cc023c95a4243
# 2  ChIJz9an_DzMJIgRx27CgzwhKxw  0x8824cc3cfca7d6cf:0x1c2b213c83c26ec7
# 3  ChIJuYuZrJ3SJIgRR7qTDPmeb1M  0x8824d29dac998bb9:0x536f9ef90c93ba47
# 4  ChIJ9_9sVxMtO4gRRCjkhzXlX98  0x883b2d13576cfff7:0xdf5fe53587e42844
#
#                data_cid                                       reviews_link  \
# 0  11246527162337556607  https://serpapi.com/search.json?data_id=0x8824...
# ...

# %%
local_results_df_2.to_csv('Location2.csv')

# %%
review_1 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJ1-8YDGMrDogRXDQtRV1VQHk', 
#                           "next_page_token": "CAESBkVnSUlDQQ==",
                         })

# %%
review_1
# Out:
# {
#     "search_metadata": {
#         "id": "6788b41abc84b862123fe2e6",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/8a67cf71c5b456d3/6788b41abc84b862123fe2e6.json",
#         "created_at": "2025-01-16 07:24:10 UTC",
#         "processed_at": "2025-01-16 07:24:10 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s0x880fd3514c69d8c1:0x182b5c1313481b77!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/6788b41abc84b862123fe2e6.html",
#         "prettify_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/6788b41abc84b862123fe2e6.prettify",
#         "total_time_taken": 0.82
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJwdhpTFHTD4gRdxtIExNcKxg",
#         "hl": "en"
#     },
#     "place_info": {
#         "title": "Divvy",
# ...

# %%
reviews_1 = review_1['reviews']

# %%
df = pd.DataFrame([{
    'Rating': reviews_1['rating'],
    'Date': reviews_1['date'],
    'ISO Date': reviews_1['iso_date'],
    'User Name': reviews_1['user']['name'],
    'Local Guide': reviews_1['user']['local_guide'],
    'User Reviews': reviews_1['user']['reviews'],
    'User Photos': reviews_1['user']['photos'],
    'Snippet': reviews_1['snippet'],
    'Likes': reviews_1['likes']
} for reviews_1 in reviews_1])

print(df)
# Out:
#    Rating         Date              ISO Date           User Name  Local Guide  \
# 0     2.0  6 years ago  2018-09-07T17:52:12Z              Todd B         True
# 1     1.0  9 years ago  2015-05-23T15:39:56Z                Nick         True
# 2     2.0  3 years ago  2021-03-22T13:46:14Z  Muhammad Saffarini         True
# 3     4.0  4 years ago  2020-01-22T16:15:36Z         Bruce Brown         True
# 4     5.0  6 years ago  2018-09-10T05:44:29Z         Edward Chau         True
# 5     2.0  6 years ago  2018-04-13T19:54:04Z         veda barnes         True
# 6     5.0  6 years ago  2018-06-21T07:48:59Z        Traci Barker         True
# 7     4.0  6 years ago  2018-10-12T20:58:50Z      Mehmet TARLACI         True
#
#    User Reviews  User Photos  \
# 0          1122         6258
# 1           174           99
# 2            43           23
# 3           350          262
# 4            74            6
# 5           143           42
# 6            74            0
# ...

# %%
df.to_csv('r1.csv')

# %%
review_2 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJwdhpTFHTD4gRdxtIExNcKxg', "next_page_token": "CAESBkVnSUlDQQ==",})

# %%
review_2
# Out:
# {
#     "search_metadata": {
#         "id": "6789348575d080b343ea8651",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/078677b180782e38/6789348575d080b343ea8651.json",
#         "created_at": "2025-01-16 16:32:05 UTC",
#         "processed_at": "2025-01-16 16:32:05 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/078677b180782e38/6789348575d080b343ea8651.html",
#         "prettify_html_file": "https://serpapi.com/searches/078677b180782e38/6789348575d080b343ea8651.prettify",
#         "total_time_taken": 1.35
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJwdhpTFHTD4gRdxtIExNcKxg",
#         "hl": "en",
#         "next_page_token": "CAESBkVnSUlDQQ=="
#     },
#     "reviews": [
#         {
# ...

# %%
reviews_2 = review_2['reviews']

# %%
df_1 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

# %%
df_1.to_csv('r2.csv')

# %%
review_21 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJ1-8YDGMrDogRXDQtRV1VQHk', 
#                           "next_page_token": "CAESBkVnSUlDQQ==",
                         })

# %%
review_21
# Out:
# {
#     "search_metadata": {
#         "id": "67893c14e2c54f8cef4ae523",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/8a67cf71c5b456d3/67893c14e2c54f8cef4ae523.json",
#         "created_at": "2025-01-16 17:04:20 UTC",
#         "processed_at": "2025-01-16 17:04:20 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s0x880e2b630c18efd7:0x7940555d452d345c!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/67893c14e2c54f8cef4ae523.html",
#         "prettify_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/67893c14e2c54f8cef4ae523.prettify",
#         "total_time_taken": 5.45
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJ1-8YDGMrDogRXDQtRV1VQHk",
#         "hl": "en"
#     },
#     "place_info": {
#         "title": "Divvy",
# ...

# %%
reviews_2 = review_21['reviews']

# %%
df_2 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

# %%
df_2.to_csv('r21.csv')

# %%
review_22 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJ1-8YDGMrDogRXDQtRV1VQHk', 
                          "next_page_token": "CAESBkVnSUlDQQ==",
                         })

# %%
review_22
# Out:
# {
#     "search_metadata": {
#         "id": "67893dfd0fb2297df68bacdb",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/078677b180782e38/67893dfd0fb2297df68bacdb.json",
#         "created_at": "2025-01-16 17:12:29 UTC",
#         "processed_at": "2025-01-16 17:12:29 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/078677b180782e38/67893dfd0fb2297df68bacdb.html",
#         "prettify_html_file": "https://serpapi.com/searches/078677b180782e38/67893dfd0fb2297df68bacdb.prettify",
#         "total_time_taken": 4.3
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJ1-8YDGMrDogRXDQtRV1VQHk",
#         "hl": "en",
#         "next_page_token": "CAESBkVnSUlDQQ=="
#     },
#     "reviews": [
#         {
# ...

# %%
reviews_2 = review_22['reviews']
df_3 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

# %%
df_3.to_csv('r22.csv')

# %%
review_31 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJa7Vf7lzTD4gRZ0oVmpXXnOQ', 
#                           "next_page_token": "CAESBkVnSUlDQQ==",
                         })

# %%
review_31
# Out:
# {
#     "search_metadata": {
#         "id": "67893f394e3622bb3b22743b",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/8a67cf71c5b456d3/67893f394e3622bb3b22743b.json",
#         "created_at": "2025-01-16 17:17:45 UTC",
#         "processed_at": "2025-01-16 17:17:45 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s0x880fd35cee5fb56b:0xe49cd7959a154a67!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/67893f394e3622bb3b22743b.html",
#         "prettify_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/67893f394e3622bb3b22743b.prettify",
#         "total_time_taken": 1.32
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJa7Vf7lzTD4gRZ0oVmpXXnOQ",
#         "hl": "en"
#     },
#     "place_info": {
#         "title": "Divvy",
# ...

# %%
reviews_2 = review_31['reviews']
df_4 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_4.head()
# Out:
#    Rating         Date              ISO Date        User Name  User Reviews  \
# 0     1.0  2 years ago  2022-06-26T05:13:37Z    Bobby Roberts             3
# 1     5.0  8 years ago  2016-06-07T02:51:59Z     Josh Siebert            23
# 2     2.0  6 years ago  2018-09-09T12:27:44Z      Race Byxbee            12
# 3     1.0  3 years ago  2021-07-30T01:10:46Z  Derrick Ristich             8
# 4     1.0  6 years ago  2018-07-05T00:29:11Z     Grant Nordby            60
#
#    User Photos                                            Snippet  \
# 0            0  These kiosks at this location simply do not wo...
# 1           21  There was supposed to be a weeknight bike vale...
# 2            0  The bikes were ok but the kiosk was very diffi...
# 3            0  Won't let me unlock my bike. Get a text and em...
# 4          105  No divvys were left and over 5 were broken. I ...
#
#                           Original Extracted Snippet  \
# 0  These kiosks at this location simply do not wo...
# ...

# %%
df_4.to_csv('r31.csv')

# %%
review_32 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJa7Vf7lzTD4gRZ0oVmpXXnOQ', 
                          "next_page_token": "CAESBkVnSUlDQQ==",
                         })

# %%
reviews_2 = review_32['reviews']
df_5 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_5.head()
# Out:
#    Rating         Date              ISO Date         User Name  User Reviews  \
# 0     5.0  5 years ago  2019-07-20T22:38:31Z  Shawntel Coulter            51
# 1     5.0  4 years ago  2020-07-01T20:08:10Z     Erik Neumayer            60
# 2     5.0  5 years ago  2020-01-11T21:13:28Z      Josh Barrett           447
# 3     1.0  9 years ago  2015-05-23T15:46:47Z              Nick           174
# 4     5.0  8 years ago  2016-11-04T11:52:23Z  Francisco Magaña           415
#
#    User Photos                                            Snippet  \
# 0            0                                          The best!
# 1            2                               Very good very good.
# 2         2636                                            Awesome
# 3           99                                        No location
# 4          370  Es genial la cantidad de sitios donde coger y ...
#
#                           Original Extracted Snippet  \
# ...

# %%
df_5.to_csv("r32.csv")

# %%
review_32
# Out:
# {
#     "search_metadata": {
#         "id": "6789404d29f264bca7e71806",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/078677b180782e38/6789404d29f264bca7e71806.json",
#         "created_at": "2025-01-16 17:22:21 UTC",
#         "processed_at": "2025-01-16 17:22:21 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/078677b180782e38/6789404d29f264bca7e71806.html",
#         "prettify_html_file": "https://serpapi.com/searches/078677b180782e38/6789404d29f264bca7e71806.prettify",
#         "total_time_taken": 1.65
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJa7Vf7lzTD4gRZ0oVmpXXnOQ",
#         "hl": "en",
#         "next_page_token": "CAESBkVnSUlDQQ=="
#     },
#     "reviews": [
#         {
# ...

# %%
review_33 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJa7Vf7lzTD4gRZ0oVmpXXnOQ', 
                          "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
review_33
# Out:
# {
#     "search_metadata": {
#         "id": "678942adc36ecd3479c5d0c2",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/c9582c99d9e2f5fc/678942adc36ecd3479c5d0c2.json",
#         "created_at": "2025-01-16 17:32:29 UTC",
#         "processed_at": "2025-01-16 17:32:29 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/c9582c99d9e2f5fc/678942adc36ecd3479c5d0c2.html",
#         "prettify_html_file": "https://serpapi.com/searches/c9582c99d9e2f5fc/678942adc36ecd3479c5d0c2.prettify",
#         "total_time_taken": 1.38
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJa7Vf7lzTD4gRZ0oVmpXXnOQ",
#         "hl": "en",
#         "next_page_token": "CAESBkVnSUlFZw=="
#     },
#     "reviews": [
#         {
# ...

# %%
reviews_2 = review_33['reviews']
df_6 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_6.head()
# Out:
#    Rating         Date              ISO Date        User Name  User Reviews  \
# 0     5.0  6 years ago  2018-08-18T22:22:05Z   Robert Young V             7
# 1     5.0  6 years ago  2018-12-10T21:25:48Z       Dave Ortiz           119
# 2     3.0  5 years ago  2019-10-13T00:52:44Z   Louis Jonckers            13
# 3     5.0  6 years ago  2018-06-06T21:57:49Z  Gabriel Fuentes            30
# 4     5.0  6 years ago  2018-12-07T06:08:10Z             Evan             6
#
#    User Photos              Snippet Original Extracted Snippet  \
# 0            0  No snippet provided        No original snippet
# 1          411  No snippet provided        No original snippet
# 2            0  No snippet provided        No original snippet
# 3           33  No snippet provided        No original snippet
# 4            0  No snippet provided        No original snippet
#
#   Translated Extracted Snippet  Likes
# 0      No translation provided      0
# 1      No translation provided      0
# ...

# %%
df_6.to_csv('r33.csv')

# %%
review_41 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJ3Wz3GqQsDogRWOoGv83INro', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_41['reviews']
df_7 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_7.head()
# Out:
#    Rating         Date              ISO Date           User Name  \
# 0     1.0  4 years ago  2020-10-15T05:34:00Z            SnakSamo
# 1     5.0  8 years ago  2016-11-26T20:42:53Z      Dennis Aguirre
# 2     5.0  6 years ago  2018-06-23T19:49:51Z       amogh zadbuke
# 3     5.0  7 years ago  2017-05-03T18:24:00Z  Taurin Tan-atichat
# 4     5.0  9 years ago  2015-12-02T17:29:28Z         Dave Mordis
#
#    User Reviews  User Photos  \
# 0             6            0
# 1            88          136
# 2            61         1654
# 3             3            1
# 4           330          394
#
#                                              Snippet  \
# 0  they kept charging me $25 and giving it back a...
# 1  With Dearborn being a major bike lane, conveni...
# 2  It was quiet easy to rent the bikes and they a...
# 3  Always bikes available at this station. And th...
# 4                               Always a bike here!!
#
#                           Original Extracted Snippet  \
# ...

# %%
df_7.to_csv("r41.csv")

# %%
review_5 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJt9uYDWrTD4gRtCtsFRAsbfA', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_5['reviews']
df_8 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_8.head(10)
# Out:
#    Rating          Date              ISO Date       User Name  User Reviews  \
# 0     1.0  9 months ago  2024-04-06T00:21:26Z    scott silbor             3
# 1     5.0   6 years ago  2018-08-17T22:12:37Z    Andrew Folts           346
# 2     4.0   7 years ago  2017-06-16T20:20:57Z    Andrew Smith            48
# 3     1.0   3 years ago  2021-09-06T19:52:32Z   Jebrone Kitty            94
# 4     4.0   6 years ago  2018-08-19T23:59:45Z    Raymond King          1192
# 5     4.0   5 years ago  2019-07-27T22:37:20Z  Amanda Yarusso             4
#
#    User Photos                                            Snippet  \
# 0            2  Had a great bike ride and returned the bike bu...
# 1          924  Great way to get around Chicago between busses...
# 2          131                            Best bike in town #tony
# 3          262  Divvy bikes are becoming increasingly run down...
# 4         3832                  Popular and convenient location..
# ...

# %%
df_8.to_csv("r5.csv")

# %%
review_6 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJY_l-xa8sDogRp6z3NC6Mq_s', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_6['reviews']
df_9 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_9.head(10)
# Out:
#    Rating          Date              ISO Date       User Name  User Reviews  \
# 0     5.0   3 years ago  2021-11-09T23:52:04Z  Brandon Hunter           126
# 1     1.0  5 months ago  2024-08-11T04:17:19Z    Brandon Ross             4
# 2     1.0  4 months ago  2024-09-11T00:46:15Z  Miriam Lorenzi            50
# 3     1.0   2 years ago  2022-09-22T08:09:15Z  Antoine Joiner             2
# 4     4.0   4 years ago  2020-01-26T19:59:41Z  ABHIJEET MUTHA            74
# 5     5.0   5 years ago  2019-07-04T18:52:46Z     Marcio Lima            52
#
#    User Photos                                            Snippet  \
# 0          276  Divvy made touring around Chicago not only a p...
# 1           25  My family and I (4 of us) wanted to rent bikes...
# 2           38  This company offers terrible customer support ...
# 3            0                                No snippet provided
# 4         1769                                No snippet provided
# ...

# %%
df_9.to_csv("r6.csv")

# %%
review_7 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJMYFly7ssDogR_JKbE_OMV3Y', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_7['reviews']
df_10 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_10.head(10)
# Out:
#    Rating         Date              ISO Date                        User Name  \
# 0     5.0  6 years ago  2018-06-23T04:13:15Z                    Garrett Stacy
# 1     5.0  2 years ago  2022-12-08T16:04:20Z  Martin Martinez González (Zito)
# 2     4.0  2 years ago  2022-12-06T00:35:55Z                     PITTER A.M.P
# 3     4.0  3 years ago  2021-07-29T16:17:40Z                     Wafa Aditiya
# 4     5.0  7 years ago  2017-07-05T13:47:28Z              Jothi Venkatachalam
#
#    User Reviews  User Photos  \
# 0            15            0
# 1           172          110
# 2            10            0
# 3             0            0
# 4            38           17
#
#                                              Snippet  \
# 0  DIvvy was an excellent way to get around downt...
# 1                                               Nice
# 2                                No snippet provided
# 3                                No snippet provided
# ...

# %%
df_10.to_csv("r7.csv")

# %%
review_8 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJwdhpTFHTD4gRWAlIXmzD8u0', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_8['reviews']
df_11 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_11.head(10)
# Out:
#    Rating          Date              ISO Date       User Name  User Reviews  \
# 0     1.0  7 months ago  2024-06-02T14:47:37Z    Haley Holmes             5
# 1     1.0   9 years ago  2015-05-23T22:17:16Z            Nick           174
# 2     1.0    a year ago  2023-05-02T02:10:59Z  John McFarland             5
# 3     5.0  2 months ago  2024-11-07T18:45:45Z    Michl Drsslr            11
# 4     5.0   5 years ago  2019-09-04T02:13:20Z   Krishna Yadav            14
# 5     4.0   5 years ago  2019-06-30T23:14:54Z      Anh N Tran            35
# 6     5.0   6 years ago  2018-08-14T05:39:04Z       Aous Odeh             4
#
#    User Photos                                            Snippet  \
# 0            8  I read the other reviews when I went to get a ...
# 1           99  Station was down, was charged an additional fe...
# 2            0  I rented a bike from this station and docked i...
# 3            0                                No snippet provided
# ...

# %%
df_11.to_csv("r8.csv")

# %%
review_9 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJY_l-xa8sDogRp6z3NC6Mq_s', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_9['reviews']
df_12 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_12.head(10)
# Out:
#    Rating          Date              ISO Date       User Name  User Reviews  \
# 0     1.0  9 months ago  2024-04-06T00:21:26Z    scott silbor             3
# 1     5.0   6 years ago  2018-08-17T22:12:37Z    Andrew Folts           346
# 2     4.0   7 years ago  2017-06-16T20:20:57Z    Andrew Smith            48
# 3     1.0   3 years ago  2021-09-06T19:52:32Z   Jebrone Kitty            94
# 4     4.0   6 years ago  2018-08-19T23:59:45Z    Raymond King          1192
# 5     4.0   5 years ago  2019-07-27T22:37:20Z  Amanda Yarusso             4
#
#    User Photos                                            Snippet  \
# 0            2  Had a great bike ride and returned the bike bu...
# 1          924  Great way to get around Chicago between busses...
# 2          131                            Best bike in town #tony
# 3          262  Divvy bikes are becoming increasingly run down...
# 4         3832                  Popular and convenient location..
# ...

# %%
df_12.to_csv("r9.csv")

# %%
review_10 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJY_l-xa8sDogRp6z3NC6Mq_s', 
#                           "next_page_token": "CAESBkVnSUlFZw==",
                         })

# %%
reviews_2 = review_10['reviews']
df_13 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_13.head(10)
# Out:
#    Rating          Date              ISO Date       User Name  User Reviews  \
# 0     5.0   3 years ago  2021-11-09T23:52:04Z  Brandon Hunter           126
# 1     1.0  5 months ago  2024-08-11T04:17:19Z    Brandon Ross             4
# 2     1.0  4 months ago  2024-09-11T00:46:15Z  Miriam Lorenzi            50
# 3     1.0   2 years ago  2022-09-22T08:09:15Z  Antoine Joiner             2
# 4     4.0   4 years ago  2020-01-26T19:59:41Z  ABHIJEET MUTHA            74
# 5     5.0   5 years ago  2019-07-04T18:52:46Z     Marcio Lima            52
#
#    User Photos                                            Snippet  \
# 0          276  Divvy made touring around Chicago not only a p...
# 1           25  My family and I (4 of us) wanted to rent bikes...
# 2           38  This company offers terrible customer support ...
# 3            0                                No snippet provided
# 4         1769                                No snippet provided
# ...

# %%
df_13.to_csv("r10.csv")

# %%
review_14 = client.search({ 'engine': 'google_maps_reviews', 'type':'search','place_id': 'ChIJ_XJ3sa3PJIgRQ0JaySPAjHA', 
#                           "next_page_token": "CAESBkVnSUlDQQ==",
                         })
reviews_2 = review_14['reviews']
df_14 = pd.DataFrame([{
    'Rating': reviews_2['rating'],
    'Date': reviews_2['date'],
    'ISO Date': reviews_2['iso_date'],
    'User Name': reviews_2['user']['name'],
    'User Reviews': reviews_2['user']['reviews'],
    'User Photos': reviews_2['user']['photos'],
    'Snippet': reviews_2.get('snippet', 'No snippet provided'),
    'Original Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('original', 'No original snippet'),
    'Translated Extracted Snippet': reviews_2.get('extracted_snippet', {}).get('translated', 'No translation provided'),
    
    'Likes': reviews_2['likes']
} for reviews_2 in reviews_2])

df_14.to_csv("r14.csv")

# %%
review_14
# Out:
# {
#     "search_metadata": {
#         "id": "6789e1d77cbf685832970d80",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/8a67cf71c5b456d3/6789e1d77cbf685832970d80.json",
#         "created_at": "2025-01-17 04:51:35 UTC",
#         "processed_at": "2025-01-17 04:51:35 UTC",
#         "google_maps_reviews_url": "https://www.google.com/maps/place/data=!4m7!3m6!1s0x883b2d5c5a9bc665:0xac851b2d0b6facba!5m2!4m1!1i2!9m1!1b1?hl=en&gl=",
#         "raw_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/6789e1d77cbf685832970d80.html",
#         "prettify_html_file": "https://serpapi.com/searches/8a67cf71c5b456d3/6789e1d77cbf685832970d80.prettify",
#         "total_time_taken": 2.65
#     },
#     "search_parameters": {
#         "engine": "google_maps_reviews",
#         "place_id": "ChIJZcabWlwtO4gRuqxvCy0bhaw",
#         "hl": "en"
#     },
#     "place_info": {
#         "title": "MoGo",
# ...

# %%
import pandas as pd
import os

# Directory containing the CSV files
directory_path = 'D:/Twitter_Project/Google_Review/Mogo'

# List to store dataframes
dataframes = []

# Read each CSV file and append to the list
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        filepath = os.path.join(directory_path, filename)
        try:
            # Try reading with UTF-8
            df = pd.read_csv(filepath)
        except UnicodeDecodeError:
            # If UTF-8 fails, try another encoding, like ISO-8859-1
            df = pd.read_csv(filepath, encoding='ISO-8859-1')
        dataframes.append(df)

# Concatenate all dataframes row-wise
combined_df = pd.concat(dataframes, axis=0, ignore_index=True)
combined_df
# Out:
#     Unnamed: 0  Rating           Date              ISO Date  \
# 0            0     2.0   3 months ago  2024-09-17T13:20:22Z
# 1            1     5.0    2 years ago  2022-11-02T18:38:28Z
# 2            2     5.0   6 months ago  2024-06-24T20:46:26Z
# 3            3     1.0   8 months ago  2024-04-27T19:22:51Z
# 4            4     5.0     a year ago  2023-03-03T19:26:05Z
# 5            5     5.0    5 years ago  2019-08-25T21:39:50Z
# 6            6     5.0    4 years ago  2020-06-17T12:43:11Z
# 7            7     1.0    4 years ago  2020-05-25T22:53:54Z
# 8            0     2.0   5 months ago  2024-08-11T20:11:05Z
# 9            0     5.0     a year ago  2023-09-30T13:09:29Z
# 10           0     5.0     a year ago  2023-02-08T01:25:04Z
# 11           1     5.0   8 months ago  2024-05-14T02:35:44Z
# 12           0     4.0     a year ago  2022-11-29T11:29:42Z
# 13           0     5.0    2 years ago  2022-09-16T05:54:35Z
# 14           0     4.0    5 years ago  2019-08-23T15:46:47Z
# ...

# %%
# Save the combined dataframe to a new CSV file
combined_df.to_csv('D:/Twitter_Project/Google_Review/Mogo/Mogo_combined_csv.csv', index=True)

print("CSV files have been combined successfully.")
# Out:
# CSV files have been combined successfully.
